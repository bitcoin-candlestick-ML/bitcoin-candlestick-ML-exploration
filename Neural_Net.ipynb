# 11      1.0  -408.29  -408.290000   605.24      3.0   201.746667  -214.24
# 12      1.0   -98.42   -98.420000   274.42      1.0   274.420000   737.89
# 13      3.0  -549.63  -183.210000  1133.40      3.0   377.800000   582.35
# 14      1.0   -65.88   -65.880000   264.03      3.0    88.010000  -260.57
# 15      1.0   -27.84   -27.840000   552.94      1.0   552.940000   148.01
# 16      1.0   -79.73   -79.730000   211.24      1.0   211.240000   -40.52
# 17      4.0  -319.60   -79.900000   545.12      6.0    90.853333   408.88
# 18      5.0 -2579.02  -515.804000  2998.71      1.0  2998.710000  2101.38
# 19      4.0 -4540.54 -1135.135000  5213.71      3.0  1737.903333  2025.80
# 20      1.0 -3078.64 -3078.640000  3115.89      2.0  1557.945000  -913.79

# %%
# convert index to column so that we can reference by event number instead of relying on index
# run only once! else restart kernal

raw.reset_index(inplace=True)
raw = raw.rename(columns = {'index':'event_number'})

# %%
raw.head()
# Out:
#    event_number       Date     Open      Low     High    Close        Volume  \
# 0             0 2017-11-24  8138.99  8090.00  8734.78  8700.01   4292.623682
# 1             1 2018-04-01  6813.01  6765.00  7125.00  7056.00  32123.560072
# 2             2 2018-08-16  6316.00  6285.40  6585.00  6584.49  57851.610803
# 3             3 2018-10-04  6591.69  6543.08  6697.00  6635.65  16096.552392
# 4             4 2019-02-07  3398.40  3373.10  3733.58  3659.04  47968.058013
#
#    Max  Min        A        B        C        D        E        F   DB  \
# 0  0.0  0.0  8212.00  8119.51  8205.92  8019.99  8700.01  9838.96  1.0
# 1  0.0  0.0  7949.30  6840.23  6923.91  6813.01  7056.00  6895.80  1.0
# 2  1.0  0.0  7024.19  6285.00  6529.79  6144.01  6584.49  6360.89  1.0
# 3  1.0  0.0  6689.13  6596.38  6626.57  6510.00  6635.65  6631.00  1.0
# 4  0.0  0.0  3569.62  3411.04  3504.77  3398.40  3659.04  3609.40  1.0
#
#    Leadup  AB_Days  AB_Vert          AB  BC_Days  BC_Vert        BC  CD_Days  \
# 0     0.0      1.0   -92.49  -92.490000      1.0    86.41   86.4100      1.0
# 1     0.0      2.0 -1109.07 -554.535000      1.0    83.68   83.6800      1.0
# 2     0.0      3.0  -739.19 -246.396667      1.0   244.79  244.7900      1.0
# 3     0.0      2.0   -92.75  -46.375000      1.0    30.19   30.1900      3.0
# 4     0.0      5.0  -158.58  -31.716000      4.0    93.73   23.4325      5.0
#
#    CD_Vert          CD  DE_Vert  DE_Days          DE       EF
# 0  -185.93 -185.930000   680.02      2.0  340.010000  1138.95
# 1  -110.90 -110.900000   242.99      1.0  242.990000  -160.20
# 2  -385.78 -385.780000   440.48      7.0   62.925714  -223.60
# 3  -116.57  -38.856667   125.65      2.0   62.825000    -4.65
# 4  -106.37  -21.274000   260.64      1.0  260.640000   -49.64

# %%
df = raw[['event_number','A','B','C','D','E','F','AB_Days','BC_Days','CD_Days','DE_Days','AB_Vert','BC_Vert','CD_Vert','DE_Vert','AB','BC','CD','DE','EF']]

# %%
df.head()
# Out:
#    event_number        A        B        C        D        E        F  \
# 0             0  8212.00  8119.51  8205.92  8019.99  8700.01  9838.96
# 1             1  7949.30  6840.23  6923.91  6813.01  7056.00  6895.80
# 2             2  7024.19  6285.00  6529.79  6144.01  6584.49  6360.89
# 3             3  6689.13  6596.38  6626.57  6510.00  6635.65  6631.00
# 4             4  3569.62  3411.04  3504.77  3398.40  3659.04  3609.40
#
#    AB_Days  BC_Days  CD_Days  DE_Days  AB_Vert  BC_Vert  CD_Vert  DE_Vert  \
# 0      1.0      1.0      1.0      2.0   -92.49    86.41  -185.93   680.02
# 1      2.0      1.0      1.0      1.0 -1109.07    83.68  -110.90   242.99
# 2      3.0      1.0      1.0      7.0  -739.19   244.79  -385.78   440.48
# 3      2.0      1.0      3.0      2.0   -92.75    30.19  -116.57   125.65
# 4      5.0      4.0      5.0      1.0  -158.58    93.73  -106.37   260.64
#
#            AB        BC          CD          DE       EF
# 0  -92.490000   86.4100 -185.930000  340.010000  1138.95
# 1 -554.535000   83.6800 -110.900000  242.990000  -160.20
# 2 -246.396667  244.7900 -385.780000   62.925714  -223.60
# 3  -46.375000   30.1900  -38.856667   62.825000    -4.65
# 4  -31.716000   23.4325  -21.274000  260.640000   -49.64

# %%
df = df.rename(columns = {'AB':'AB_avg_change_per_day','BC':'BC_avg_change_per_day','CD':'CD_avg_change_per_day','DE':'DE_avg_change_per_day','EF':'EF_avg_change_per_day'})

# %%
df.head()
# Out:
#    event_number        A        B        C        D        E        F  \
# 0             0  8212.00  8119.51  8205.92  8019.99  8700.01  9838.96
# 1             1  7949.30  6840.23  6923.91  6813.01  7056.00  6895.80
# 2             2  7024.19  6285.00  6529.79  6144.01  6584.49  6360.89
# 3             3  6689.13  6596.38  6626.57  6510.00  6635.65  6631.00
# 4             4  3569.62  3411.04  3504.77  3398.40  3659.04  3609.40
#
#    AB_Days  BC_Days  CD_Days  DE_Days  AB_Vert  BC_Vert  CD_Vert  DE_Vert  \
# 0      1.0      1.0      1.0      2.0   -92.49    86.41  -185.93   680.02
# 1      2.0      1.0      1.0      1.0 -1109.07    83.68  -110.90   242.99
# 2      3.0      1.0      1.0      7.0  -739.19   244.79  -385.78   440.48
# 3      2.0      1.0      3.0      2.0   -92.75    30.19  -116.57   125.65
# 4      5.0      4.0      5.0      1.0  -158.58    93.73  -106.37   260.64
#
#    AB_avg_change_per_day  BC_avg_change_per_day  CD_avg_change_per_day  \
# 0             -92.490000                86.4100            -185.930000
# 1            -554.535000                83.6800            -110.900000
# 2            -246.396667               244.7900            -385.780000
# 3             -46.375000                30.1900             -38.856667
# 4             -31.716000                23.4325             -21.274000
#
#    DE_avg_change_per_day  EF_avg_change_per_day
# 0             340.010000                1138.95
# 1             242.990000                -160.20
# 2              62.925714                -223.60
# 3              62.825000                  -4.65
# 4             260.640000                 -49.64

# %%
df['AB_percent_change_per_day']= df['AB_avg_change_per_day']/df['A']
df['BC_percent_change_per_day']= df['BC_avg_change_per_day']/df['B']
df['CD_percent_change_per_day']= df['CD_avg_change_per_day']/df['C']
df['DE_percent_change_per_day']= df['DE_avg_change_per_day']/df['D']
df['EF_percent_change_per_day']= df['EF_avg_change_per_day']/df['E']

# %%
df['bs_1_or_sb_0']=np.where((df['F']>df['E']),'1','0')

# %%
df.head()
# Out:
#    event_number        A        B        C        D        E        F  \
# 0             0  8212.00  8119.51  8205.92  8019.99  8700.01  9838.96
# 1             1  7949.30  6840.23  6923.91  6813.01  7056.00  6895.80
# 2             2  7024.19  6285.00  6529.79  6144.01  6584.49  6360.89
# 3             3  6689.13  6596.38  6626.57  6510.00  6635.65  6631.00
# 4             4  3569.62  3411.04  3504.77  3398.40  3659.04  3609.40
#
#    AB_Days  BC_Days  CD_Days  DE_Days  AB_Vert  BC_Vert  CD_Vert  DE_Vert  \
# 0      1.0      1.0      1.0      2.0   -92.49    86.41  -185.93   680.02
# 1      2.0      1.0      1.0      1.0 -1109.07    83.68  -110.90   242.99
# 2      3.0      1.0      1.0      7.0  -739.19   244.79  -385.78   440.48
# 3      2.0      1.0      3.0      2.0   -92.75    30.19  -116.57   125.65
# 4      5.0      4.0      5.0      1.0  -158.58    93.73  -106.37   260.64
#
#    AB_avg_change_per_day  BC_avg_change_per_day  CD_avg_change_per_day  \
# 0             -92.490000                86.4100            -185.930000
# 1            -554.535000                83.6800            -110.900000
# 2            -246.396667               244.7900            -385.780000
# 3             -46.375000                30.1900             -38.856667
# 4             -31.716000                23.4325             -21.274000
#
#    DE_avg_change_per_day  EF_avg_change_per_day  AB_percent_change_per_day  \
# 0             340.010000                1138.95                  -0.011263
# 1             242.990000                -160.20                  -0.069759
# 2              62.925714                -223.60                  -0.035078
# 3              62.825000                  -4.65                  -0.006933
# 4             260.640000                 -49.64                  -0.008885
#
#    BC_percent_change_per_day  CD_percent_change_per_day  \
# 0                   0.010642                  -0.022658
# 1                   0.012234                  -0.016017
# 2                   0.038948                  -0.059080
# 3                   0.004577                  -0.005864
# 4                   0.006870                  -0.006070
#
#    DE_percent_change_per_day  EF_percent_change_per_day bs_1_or_sb_0
# 0                   0.042395                   0.130914            1
# 1                   0.035666                  -0.022704            0
# 2                   0.010242                  -0.033959            0
# 3                   0.009651                  -0.000701            0
# 4                   0.076695                  -0.013566            0

# %%
df['AB_Days'].value_counts()
# Out:
# 2.0     8
# 1.0     7
# 3.0     3
# 5.0     1
# 14.0    1
# 20.0    1
# Name: AB_Days, dtype: int64

# %%
# our train set should be 80-85% of the number of inputs. Let's start with 80%:
21*.8
# Out:
# 16.8

# %%
# time to train our model!

from sklearn.model_selection import train_test_split

train_data, test_data = np.split(df, [int(.80*len(df))])

test = test_data
train = train_data
target = 'bs_1_or_sb_0'
train, val = train_test_split(train, test_size=0.2,  
                              stratify=train[target])
features = train.columns

X_train = train.drop(columns=target)
y_train = train[target]
X_test = test.drop(columns=target)
y_test = test[target]
X_val = val.drop(columns=target)
y_val = val[target]
print(features)
# Out:
# Index(['event_number', 'A', 'B', 'C', 'D', 'E', 'F', 'AB_Days', 'BC_Days',
#        'CD_Days', 'DE_Days', 'AB_Vert', 'BC_Vert', 'CD_Vert', 'DE_Vert',
#        'AB_avg_change_per_day', 'BC_avg_change_per_day',
#        'CD_avg_change_per_day', 'DE_avg_change_per_day',
#        'EF_avg_change_per_day', 'AB_percent_change_per_day',
#        'BC_percent_change_per_day', 'CD_percent_change_per_day',
#        'DE_percent_change_per_day', 'EF_percent_change_per_day',
#        'bs_1_or_sb_0'],
#       dtype='object')

# %%
print(train_data.shape)
train_data.head()
# Out:
# (16, 26)
#    event_number        A        B        C        D        E        F  \
# 0             0  8212.00  8119.51  8205.92  8019.99  8700.01  9838.96
# 1             1  7949.30  6840.23  6923.91  6813.01  7056.00  6895.80
# 2             2  7024.19  6285.00  6529.79  6144.01  6584.49  6360.89
# 3             3  6689.13  6596.38  6626.57  6510.00  6635.65  6631.00
# 4             4  3569.62  3411.04  3504.77  3398.40  3659.04  3609.40
#
#    AB_Days  BC_Days  CD_Days  DE_Days  AB_Vert  BC_Vert  CD_Vert  DE_Vert  \
# 0      1.0      1.0      1.0      2.0   -92.49    86.41  -185.93   680.02
# 1      2.0      1.0      1.0      1.0 -1109.07    83.68  -110.90   242.99
# 2      3.0      1.0      1.0      7.0  -739.19   244.79  -385.78   440.48
# 3      2.0      1.0      3.0      2.0   -92.75    30.19  -116.57   125.65
# 4      5.0      4.0      5.0      1.0  -158.58    93.73  -106.37   260.64
#
#    AB_avg_change_per_day  BC_avg_change_per_day  CD_avg_change_per_day  \
# 0             -92.490000                86.4100            -185.930000
# 1            -554.535000                83.6800            -110.900000
# 2            -246.396667               244.7900            -385.780000
# 3             -46.375000                30.1900             -38.856667
# 4             -31.716000                23.4325             -21.274000
#
#    DE_avg_change_per_day  EF_avg_change_per_day  AB_percent_change_per_day  \
# 0             340.010000                1138.95                  -0.011263
# 1             242.990000                -160.20                  -0.069759
# 2              62.925714                -223.60                  -0.035078
# 3              62.825000                  -4.65                  -0.006933
# 4             260.640000                 -49.64                  -0.008885
#
#    BC_percent_change_per_day  CD_percent_change_per_day  \
# 0                   0.010642                  -0.022658
# 1                   0.012234                  -0.016017
# 2                   0.038948                  -0.059080
# 3                   0.004577                  -0.005864
# 4                   0.006870                  -0.006070
#
#    DE_percent_change_per_day  EF_percent_change_per_day bs_1_or_sb_0
# 0                   0.042395                   0.130914            1
# 1                   0.035666                  -0.022704            0
# 2                   0.010242                  -0.033959            0
# 3                   0.009651                  -0.000701            0
# 4                   0.076695                  -0.013566            0

# %%
print(test_data.shape)
test_data.head()
# Out:
# (5, 26)
#     event_number         A         B         C         D         E         F  \
# 16            16  11762.46  11594.23  11761.41  11681.68  11892.92  11852.40
# 17            17  11921.97  10140.85  10446.25  10126.65  10671.77  11080.65
# 18            18  36631.27  30850.13  32945.17  30366.15  33364.86  35466.24
# 19            19  57408.57  48891.00  49676.20  45135.66  50349.37  52375.17
# 20            20  35600.16  31608.93  34663.09  31584.45  34700.34  33786.55
#
#     AB_Days  BC_Days  CD_Days  DE_Days  AB_Vert  BC_Vert  CD_Vert  DE_Vert  \
# 16      1.0      1.0      1.0      1.0  -168.23   167.18   -79.73   211.24
# 17      2.0      1.0      4.0      6.0 -1781.12   305.40  -319.60   545.12
# 18      3.0      1.0      5.0      1.0 -5781.14  2095.04 -2579.02  2998.71
# 19      2.0      1.0      4.0      3.0 -8517.57   785.20 -4540.54  5213.71
# 20      1.0      3.0      1.0      2.0 -3991.23  3054.16 -3078.64  3115.89
#
#     AB_avg_change_per_day  BC_avg_change_per_day  CD_avg_change_per_day  \
# 16            -168.230000             167.180000                -79.730
# 17            -890.560000             305.400000                -79.900
# 18           -1927.046667            2095.040000               -515.804
# 19           -4258.785000             785.200000              -1135.135
# 20           -3991.230000            1018.053333              -3078.640
#
#     DE_avg_change_per_day  EF_avg_change_per_day  AB_percent_change_per_day  \
# 16             211.240000                 -40.52                  -0.014302
# 17              90.853333                 408.88                  -0.074699
# 18            2998.710000                2101.38                  -0.052607
# 19            1737.903333                2025.80                  -0.074184
# 20            1557.945000                -913.79                  -0.112113
#
#     BC_percent_change_per_day  CD_percent_change_per_day  \
# 16                   0.014419                  -0.006779
# 17                   0.030116                  -0.007649
# 18                   0.067910                  -0.015656
# 19                   0.016060                  -0.022851
# 20                   0.032208                  -0.088816
#
#     DE_percent_change_per_day  EF_percent_change_per_day bs_1_or_sb_0
# 16                   0.018083                  -0.003407            0
# 17                   0.008972                   0.038314            1
# 18                   0.098752                   0.062982            1
# 19                   0.038504                   0.040235            1
# 20                   0.049326                  -0.026334            0

# %%
y_test
# Out:
# 16    0
# 17    1
# 18    1
# 19    1
# 20    0
# Name: bs_1_or_sb_0, dtype: object

# %%
# here we're preparing to do a logistic regression model

import sys
import category_encoders as ce

from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

encoder = ce.OneHotEncoder(use_cat_names=True)
imputer = SimpleImputer()
scaler = StandardScaler()
model = LogisticRegression(max_iter=1000,solver='lbfgs')

X_train_encoded = encoder.fit_transform(X_train)
X_train_imputed = imputer.fit_transform(X_train_encoded)
X_train_scaled = scaler.fit_transform(X_train_imputed)
model.fit(X_train_scaled, y_train)

X_test_encoded = encoder.transform(X_test)
X_test_imputed = imputer.transform(X_test_encoded)
X_test_scaled = scaler.transform(X_test_imputed)
y_pred = model.predict(X_test_scaled)
y_pred
# Out:
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# array(['0', '1', '0', '0', '0'], dtype=object)

# %%
model.score(X_train_scaled,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_absolute_error, r2_score

guess = df['bs_1_or_sb_0'].mean()
y_pred = [guess] * len(y_train)
mae = mean_absolute_error(y_train, y_pred)
print(f'Train Error: {mae:.2f}')
r2 = r2_score(y_train, y_pred)
print('R squared: ', r2)
# Out:
# Train Error: 4761957619052862464.00
# R squared:  -9.329653179012592e+37

# %%
X_train.head()
# Out:
#     event_number         A         B         C         D         E         F  \
# 12            12   8736.03   8404.52   8439.00   8340.58   8615.00   9352.89
# 9              9  10415.01   8063.73   8198.81   8043.82   8289.34   8126.19
# 8              8  11549.97  10050.37  10331.54  10216.02  10915.54  10134.35
# 5              5   4117.76   3743.56   3827.92   3715.30   3857.73   3916.82
# 14            14   7361.28   6858.92   6903.79   6837.91   7101.94   6841.37
#
#     AB_Days  BC_Days  CD_Days  DE_Days  AB_Vert  BC_Vert  CD_Vert  DE_Vert  \
# 12      2.0      1.0      1.0      1.0  -331.51    34.48   -98.42   274.42
# 9      14.0      2.0      1.0      1.0 -2351.28   135.08  -154.99   245.52
# 8       3.0      2.0      1.0      2.0 -1499.60   281.17  -115.52   699.52
# 5       1.0      1.0      7.0      1.0  -374.20    84.36  -112.62   142.43
# 14      2.0      2.0      1.0      3.0  -502.36    44.87   -65.88   264.03
#
#     AB_avg_change_per_day  BC_avg_change_per_day  CD_avg_change_per_day  \
# 12            -165.755000                 34.480             -98.420000
# 9             -167.948571                 67.540            -154.990000
# 8             -499.866667                140.585            -115.520000
# 5             -374.200000                 84.360             -16.088571
# 14            -251.180000                 22.435             -65.880000
#
#     DE_avg_change_per_day  EF_avg_change_per_day  AB_percent_change_per_day  \
# 12                 274.42                 737.89                  -0.018974
# 9                  245.52                -163.15                  -0.016126
# 8                  349.76                -781.19                  -0.043279
# 5                  142.43                  59.09                  -0.090875
# 14                  88.01                -260.57                  -0.034122
#
#     BC_percent_change_per_day  CD_percent_change_per_day  \
# 12                   0.004103                  -0.011663
# 9                    0.008376                  -0.018904
# 8                    0.013988                  -0.011181
# 5                    0.022535                  -0.004203
# 14                   0.003271                  -0.009543
#
#     DE_percent_change_per_day  EF_percent_change_per_day
# 12                   0.032902                   0.085652
# 9                    0.030523                  -0.019682
# 8                    0.034236                  -0.071567
# 5                    0.038336                   0.015317
# 14                   0.012871                  -0.036690

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, chi2, f_regression

selector = SelectKBest(k="all")

X_train_selected = selector.fit_transform(X_train, y_train)

# %%
X_train_selected.shape
# Out:
# (12, 25)

# %%
selected_mask = selector.get_support()
all_names = X_train.columns
selected_names = all_names[selected_mask]
unselected_names = all_names[~selected_mask]

print('Features selected:')
for name in selected_names:
    print(name)

print('\n')
print('Features not selected:')
for name in unselected_names:
    print(name)
# Out:
# Features selected:
# event_number
# A
# B
# C
# D
# E
# F
# AB_Days
# BC_Days
# CD_Days
# DE_Days
# AB_Vert
# BC_Vert
# CD_Vert
# DE_Vert
# AB_avg_change_per_day
# BC_avg_change_per_day
# CD_avg_change_per_day
# DE_avg_change_per_day
# EF_avg_change_per_day
# AB_percent_change_per_day
# BC_percent_change_per_day
# CD_percent_change_per_day
# DE_percent_change_per_day
# EF_percent_change_per_day
#
#
# Features not selected:

# %%
encoder = ce.OneHotEncoder(use_cat_names=True)
X_val = encoder.fit_transform(X_val)
# Out:
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

for k in range(1, len(X_train.columns) + 1):
  print(f'{k} features')

  selector = SelectKBest(k=k)
  X_train_selected = selector.fit_transform(X_train, y_train)
  X_test_selected = selector.transform(X_val)

  model = LinearRegression()
  model.fit(X_train_selected, y_train)
  y_pred = model.predict(X_test_selected)
  mae = mean_absolute_error(y_val, y_pred)
  print(f'Test MAE: {mae:,.4f} \n')
# Out:
# 1 features
# Test MAE: 0.3412
#
# 2 features
# Test MAE: 0.2553
#
# 3 features
# Test MAE: 0.2512
#
# 4 features
# Test MAE: 0.2717
#
# 5 features
# Test MAE: 0.4465
#
# 6 features
# Test MAE: 0.4470
#
# 7 features
# Test MAE: 0.4557
#
# 8 features
# Test MAE: 0.5271
#
# 9 features
# Test MAE: 0.4710
#
# 10 features
# Test MAE: 0.4924
#
# 11 features
# Test MAE: 0.6606
#
# 12 features
# Test MAE: 0.8587
#
# 13 features
# Test MAE: 0.8984
#
# 14 features
# Test MAE: 0.9328
#
# 15 features
# Test MAE: 0.9328
#
# 16 features
# Test MAE: 0.9328
#
# 17 features
# Test MAE: 0.9328
#
# 18 features
# Test MAE: 1.8943
#
# 19 features
# Test MAE: 1.8948
#
# 20 features
# Test MAE: 1.8913
#
# 21 features
# Test MAE: 1.8940
#
# 22 features
# Test MAE: 2.2680
#
# 23 features
# Test MAE: 2.2679
#
# 24 features
# Test MAE: 4.3431
#
# 25 features
# Test MAE: 4.3499

# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge

for alpha in [0.00000000001, 0.00001, 0.001, .1]:
    
    # Fit Ridge Regression model
    display(HTML(f'Ridge Regression, with alpha={alpha}'))
    model = Ridge(alpha=alpha, normalize=True)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)

    # Get Test MAE
    mae = mean_absolute_error(y_val, y_pred)
    display(HTML(f'Test Mean Absolute Error: {mae:,.4f}'))
    
    # Plot coefficients
    coefficients = pd.Series(model.coef_, X_train.columns)
    plt.figure(figsize=(16,8))
    coefficients.sort_values().plot.barh(color='blue')
    plt.xlim(-5,5)
    plt.show()
# Out:
# Ridge Regression, with alpha=1e-11
# Test Mean Absolute Error: 0.5982
# Ridge Regression, with alpha=1e-05
# Test Mean Absolute Error: 0.5980
# Ridge Regression, with alpha=0.001
# Test Mean Absolute Error: 0.5748
# Ridge Regression, with alpha=0.1
# Test Mean Absolute Error: 0.4216

# %%
# alpha at .1 seems to be the lowest MAE that I tested and the other alphas 
# don't go any lower than MAE of .5329 so we'll go with that
linridge = Ridge(alpha=0.1).fit(X_train, y_train)

print('R-squared score (train): {:.3f}'
     .format(linridge.score(X_train, y_train)))
# Out:
# R-squared score (train): 1.000

# %%
linridge = Ridge(alpha=0.1).fit(X_val, y_val)

print('R-squared score (validate): {:.3f}'
     .format(linridge.score(X_val, y_val)))
# Out:
# R-squared score (validate): 1.000

# %% [raw]
# It seems like linear regression may do a very good job at explaining variability of our target (since ideally we'd want an R-squared score of at least 80% but our R-squared scores are 100% for both train and test sets).

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

pipeline = make_pipeline(
    ce.OneHotEncoder(use_cat_names=True), 
    SimpleImputer(strategy='mean'), 
    StandardScaler(), 
    SelectKBest(k=18), 
    Ridge(alpha=0.1)
)

k = 3
scoresLM = cross_val_score(pipeline, X_train, y_train, cv=k, 
                         scoring='neg_mean_absolute_error')
print(f'MAE for {k} folds:', -scoresLM)
# Out:
# MAE for 3 folds: [0.34511929 0.82626435 0.42445817]
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
-scoresLM.mean()
# Out:
# 0.5319472708252999

# %%
# I had trouble loading xgboost for some reason- I used the following command in terminal
# conda install -c conda-forge xgboost

from xgboost import XGBClassifier

pipeline101 = make_pipeline(
    ce.OrdinalEncoder(),
    XGBClassifier(n_estimators=100,
                  random_state=42,
                  n_jobs=-1)
)
pipeline101.fit(X_train, y_train)
# Out:
# [00:08:30] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder(cols=[], mapping=[])),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, gpu_id=-1,
#                                importance_type='gain',
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=-1, num_parallel_tree=1, random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                subsample=1, tree_method='exact',
#                                validate_parameters=1, verbosity=None))])

# %%
from sklearn.metrics import accuracy_score

y_pred = pipeline101.predict(X_test)
print('Training Accuracy:', pipeline101.score(X_train, y_train))
print('Validation Accuracy:', pipeline101.score(X_val, y_val))
print('Test Accuracy', accuracy_score(y_test, y_pred))
# Out:
# Training Accuracy: 1.0
# Validation Accuracy: 1.0
# Test Accuracy 1.0

# %%
k = 2
scoresLMp101 = cross_val_score(pipeline101, X_train, y_train, cv=k, 
                         scoring='neg_mean_absolute_error')
print(f'MAE for {k} folds:', -scoresLMp101)
print(f'Mean of cross-validation scores for {k} folds:',-scoresLMp101.mean())
# Out:
# [00:56:17] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:56:17] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# MAE for 2 folds: [0.5        0.33333333]
# Mean of cross-validation scores for 2 folds: 0.41666666666666663
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
# !pip install eli5

import eli5
from eli5.sklearn import PermutationImportance

# Ignore warnings

transformers = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

X_train_transformed = transformers.fit_transform(X_train)
X_val_transformed = transformers.transform(X_val)

pipeline103 = make_pipeline(
    ce.OrdinalEncoder(),
    XGBClassifier(booster= 'gbtree',n_estimators=30, max_depth=5,
                  random_state=30,
                  n_jobs=-1)
)
pipeline103.fit(X_train_transformed, y_train)


feature_names = X_val.columns.tolist()

permuter = PermutationImportance(
    pipeline103,
    scoring='accuracy',
    n_iter=5,
    random_state=42
)

permuter.fit(X_val_transformed, y_val)

eli5.show_weights(
    permuter,
    top=None,
    feature_names=feature_names
)
# Out:
# Collecting eli5
#   Downloading eli5-0.11.0-py2.py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 4.4 MB/s eta 0:00:01
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: scipy in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from eli5) (1.6.2)
# Collecting graphviz
#   Downloading graphviz-0.17-py3-none-any.whl (18 kB)
# Requirement already satisfied: jinja2 in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from eli5) (2.11.3)
# Requirement already satisfied: numpy>=1.9.0 in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from eli5) (1.20.1)
# Requirement already satisfied: scikit-learn>=0.20 in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from eli5) (0.24.2)
# Requirement already satisfied: attrs>16.0.0 in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from eli5) (20.3.0)
# Requirement already satisfied: six in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from eli5) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from scikit-learn>=0.20->eli5) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from scikit-learn>=0.20->eli5) (2.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages (from jinja2->eli5) (2.0.1)
# Installing collected packages: tabulate, graphviz, eli5
# Successfully installed eli5-0.11.0 graphviz-0.17 tabulate-0.8.9
# [00:57:20] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/shannonli/opt/anaconda3/envs/ColFinTech/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4000
#
#                     &plusmn; 0.7483
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EF_avg_change_per_day
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EF_percent_change_per_day
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AB_Vert
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 A
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 B
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 C
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 D
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 E
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 F
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AB_Days
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BC_Days
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CD_Days
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DE_Days
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BC_Vert
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DE_percent_change_per_day
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CD_Vert
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DE_Vert
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AB_avg_change_p

# %% [raw]
# ^it was at that point I realized that I was incorporating a measure of f as a predictor of f. Time to reshape my dataframe.
